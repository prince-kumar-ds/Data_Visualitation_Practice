# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y='tip',hue='day',size='sex',style='size',col='time',row='smoker',data=df);

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
sns.relplot(x='total_bill',y='tip',kind='line',data=df);

# %%
sns.lineplot(x='total_bill',y='tip',data=df);

# %%
sns.scatterplot(x='total_bill',y='tip',data=df);

# %%
sns.catplot(x='day',y='total_bill',hue='day',data=df);

# %%
sns.catplot(x='day',y='total_bill',hue='sex',kind='swarm',data=df);

# %%
df.groupby('day')['total_bill'].sum()
# Out:
# day
# Thur    1096.33
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Name: total_bill, dtype: float64

# %%
sns.barplot(x='day',y='total_bill',estimator='max',hue='sex',ci=None,data=df);

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
sns.histplot(x='sex',data=df);

# %%
sns.countplot(x='sex',data=df);

# %%
sns.catplot(x='day',y='total_bill',hue='sex',kind='bar',ci=None,data=df);

# %%
sns.catplot(x='sex',kind='count',data=df);

# %%
sns.boxplot(y='tip',data=df);

# %%
sns.boxplot(x='day',y='tip',hue='sex',data=df);

# %%
plt.figure(figsize=(4,6))
sns.catplot(x='day',y='tip',hue='sex',kind='violin',data=df);

# %%
a=np.random.randn(100000)
a
# Out:
# array([-2.78612236,  0.83606281, -1.36728898, ..., -1.53931349,
#         0.60878231, -0.51502814], shape=(100000,))

# %%
sns.distplot(a);
